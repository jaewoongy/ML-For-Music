# %%
import os
from glob import glob
import numpy as np
import random

# %%
import homework3
# Out:
# 6087
# 5976
# 5010
# 19315
# 17023
# 9395
# 12003
# 19834
# 9400
# 9714
# 15518
# 6921
# 6442
# 2628
# 2128
# 2223
# 729
# 291
# 1309
# 922
# 771
# 696
# 457
# 326
# 65
# 435
# 327
# 178
# 75
# 29
# 15
# 146
# 13
# 103
# 42
# 1
# 13
# 1
# 16
# 16
# 16
# 14
# 6
# 2
# 2
# 2

# %%
random.seed(0)

# %%
midi_files = glob('PDMX_subset/*.mid')
# Note: the autograder will only use a subset of the files.
# You might also work with a small subset to make experimentation faster

# %%
def testQ1a():
    yours = homework3.note_extraction(midi_files[2])
    print(yours)

testQ1a()
# Out:
# [69, 67, 64, 69, 69, 71, 74, 72, 71, 69, 67, 71, 74, 72, 71, 69, 67, 62, 64, 69, 69, 71, 72, 74, 76, 78, 79, 76, 74, 71, 76, 69, 71, 69, 67, 64, 69, 69, 71, 74, 72, 71, 69, 67, 71, 74, 72, 71, 67, 67, 62, 64, 69, 69, 71, 72, 74, 76, 78, 81, 79, 76, 74, 71, 76, 69, 69, 79]

# %%
def testQ1b():
    yours = homework3.note_frequency(midi_files)
    print(yours)

testQ1b()
# Out:
# defaultdict(<class 'int'>, {66: 6087, 64: 5976, 62: 5010, 69: 19315, 71: 17023, 72: 9395, 67: 12003, 74: 19834, 79: 9400, 78: 9714, 76: 15518, 73: 6921, 81: 6442, 77: 2628, 70: 2128, 65: 2223, 60: 729, 82: 291, 83: 1309, 80: 922, 68: 771, 75: 696, 57: 457, 61: 326, 85: 65, 59: 435, 63: 327, 55: 178, 52: 75, 53: 29, 50: 15, 84: 146, 88: 13, 58: 103, 86: 42, 54: 1, 56: 13, 92: 1, 35: 16, 37: 16, 48: 16, 43: 14, 36: 6, 45: 2, 38: 2, 47: 2})

# %%
def testQ2():
    yours = homework3.note_unigram_probability(midi_files)
    print(yours)

testQ2()
# Out:
# {66: 0.038861046381715454, 64: 0.038152392504868, 62: 0.03198518849554697, 69: 0.12331215884061672, 71: 0.10867941392409104, 72: 0.059980208765601555, 67: 0.07663038273693619, 74: 0.1266255945350656, 79: 0.0600121301114055, 78: 0.06201679062789287, 76: 0.09907108883710537, 73: 0.04418552686181249, 81: 0.04112746193379513, 77: 0.016777859354550388, 70: 0.013585724774156479, 65: 0.01419223034443132, 60: 0.00465413221821432, 82: 0.0018578223257892552, 83: 0.008357008331471254, 80: 0.005886296166246369, 68: 0.004922271522967409, 75: 0.004443451335908322, 57: 0.002917611006480033, 61: 0.002081271746416829, 85: 0.00041497749545120824, 59: 0.002777157084942701, 63: 0.0020876560155776167, 55: 0.0011363999106202317, 52: 0.0004788201870590864, 53: 0.00018514380566284674, 50: 9.576403741181728e-05, 84: 0.0009321032974750215, 88: 8.299549909024164e-05, 58: 0.0006575797235611453, 86: 0.0002681393047530884, 54: 6.3842691607878185e-06, 56: 8.299549909024164e-05, 92: 6.3842691607878185e-06, 35: 0.0001021483065726051, 37: 0.0001021483065726051, 48: 0.0001021483065726051, 43: 8.937976825102947e-05, 36: 3.8305614964726914e-05, 45: 1.2768538321575637e-05, 38: 1.2768538321575637e-05, 47: 1.2768538321575637e-05}

# %%
def testQ3a():
    your_transition, your_probability = homework3.note_bigram_probability(midi_files)
    print(your_transition[74]) # Example
    print(your_probability[74])

# %%
def testQ3b():
    test_notes = [92, 35, 54] # some notes that have only one possible next note
    yours = []
    correct = []
    for note in test_notes:
        yours.append(homework3.sample_next_note(note))

    print(yours)

# %%
def testQ4():
    test_file = midi_files[0]
    yours = [homework3.note_bigram_perplexity(test_file)]
    print(yours)

# %%
def testQ5a():
    test_notes = [71,72,73]
    your_transition, your_probability = homework3.note_trigram_probability(midi_files)
    print(your_transition)
    print(your_probability)

# %%
def testQ5b():
    test_file = midi_files[0]
    yours = [homework3.note_trigram_perplexity(test_file)]
    print(yours)

# %%
def testQ6():
    test_files = midi_files[:5]
    yours = []
    for file in test_files:
        beats = homework3.beat_extraction(file)
        yours += [beat[0] for beat in beats]
        yours += [beat[1] for beat in beats]

    print(yours)

# %%
def testQ7():
    test_beats = [2,4,8]
    your_transition, your_probability = homework3.beat_bigram_probability(midi_files)
    yours = []
    correct = []
    for note in test_beats:
        index = your_transition[4].index(note)
        yours.append(your_probability[4][index])

    print(yours)

# %%
def testQ8a():
    test_beats = [2,4,8]
    your_transition, your_probability = homework3.beat_pos_bigram_probability(midi_files)
    yours = []
    for note in test_beats:
        index = your_transition[0].index(note)
        yours.append(your_probability[0][index])

    print(yours)

# %%
def testQ8b():
    test_file = midi_files[0]
    yours = list(homework3.beat_bigram_perplexity(test_file))
    print(yours)

# %%
def testQ9a():
    test_beats = [2,4,8]
    your_transition, your_probability = homework3.beat_trigram_probability(midi_files)
    yours = []
    for note in test_beats:
        index = your_transition[(4, 0)].index(note)
        yours.append(your_probability[(4, 0)][index])

    print(yours)

# %%
def testQ9b():
    test_file = midi_files[0]
    yours = [homework3.beat_trigram_perplexity(test_file)]

    print(yours)

# %%
def testQ10():
    homework3.music_generate(n)
    if not os.path.exists('q10.mid'):
        print('No q10.mid file found')
        return 0

    # requirement1: generation of n notes
    notes = homework3.note_extraction('q10.mid')
    if len(notes) == n:
        point += 0.25
    else:
        print('It looks like your solution has the wrong sequence length')

    # Various other tests about the statistics of your midi file...
